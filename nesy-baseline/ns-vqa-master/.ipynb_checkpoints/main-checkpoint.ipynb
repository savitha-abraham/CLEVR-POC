# %%
#! nvidia-smi

# %%
#!git config --global user.email "savitha.sam-abraham@oru.se"
#!git config --global user.name "savitha-abraham"

# %%
#%cd drive/MyDrive/CLEVR-ABDUCTIVE
#!git add -u

# %%
#!git config --global user.email "savitha.sam-abraham@oru.se"
#!git config --global user.name "savitha-abraham"

# %%
#!git remote set-url origin https://savitha-abraham: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@github.com/savitha-abraham/CLEVR-ABDUCTIVE.git

# %%
#%cd drive/MyDrive/CLEVR-ABDUCTIVE
#!git commit -m "01-07"
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/CLEVR-ABDUCTIVE'
# /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
# [master 15bed37] 01-07
#  24 files changed, 10 insertions(+), 10 deletions(-)
#  rewrite nesy/ns-vqa-master/main.ipynb (94%)
#  rewrite nesy/ns-vqa-master/reason/datasets/__pycache__/clevr_questions.cpython-37.pyc (69%)

# %%
#!git push
# Out:
# Counting objects: 43, done.
# Delta compression using up to 8 threads.
# Compressing objects: 100% (39/39), done.
# Writing objects: 100% (43/43), 103.28 KiB | 2.40 MiB/s, done.
# Total 43 (delta 12), reused 0 (delta 0)
# remote: Resolving deltas: 100% (12/12), completed with 11 local objects.
# To https://github.com/savitha-abraham/CLEVR-ABDUCTIVE.git
#    ae88f4e..15bed37  master -> master

# %%
#!git remote -v

# %%
#!lspci | grep ' VGA ' | cut -d" " -f 1 | xargs -i lspci -v -s {}

# %%
#! nvcc --version

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
import sys
sys.path.append('/content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason/tools')

# %%
#PRECOMPUTE
#%cd /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
#%run executors/precompute.py

# %%
#PREPROCESS TRAIN
# %cd reason
#%run tools/preprocess_questions.py \
#--input_questions_json=../data/raw/CLEVR_v1.0/questions/CLEVR_train_questions.json \
#--output_h5_file=../data/reason/clevr_h5_3000/clevr_train_questions_pre.h5 \
#--input_vocab_json=../data/reason/clevr_h5_3000/clevr_vocab_pre.json
# %run tools/preprocess_questions.py \
--input_questions_json=/home/savitha/Documents/clevr-poc/CLEVR-POC/clevr-poc-dataset-gen/data/output-2000/incomplete/questions/training \
--output_h5_file=/home/savitha/Documents/clevr-poc/CLEVR-POC/nesy-baseline/ns-vqa-master/data/reason/output-2000/clevr-poc-train_questions.h5 \
--output_vocab_json=/home/savitha/Documents/clevr-poc/CLEVR-POC/nesy-baseline/ns-vqa-master/data/reason/output-2000/clevr-poc-vocab.json \
--input_scenes_json=/home/savitha/Documents/clevr-poc/CLEVR-POC/clevr-poc-dataset-gen/data/output-2000/incomplete/scenes/training
# Out:
# /home/savitha/Documents/clevr-poc/CLEVR-POC/nesy-baseline/ns-vqa-master/reason
# a
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Documents/clevr-poc/CLEVR-POC/nesy-baseline/ns-vqa-master/reason/tools/preprocess_questions.py in <module>
#     278 if __name__ == '__main__':
#     279     args = parser.parse_args()
# --> 280     main(args)
#
# ~/Documents/clevr-poc/CLEVR-POC/nesy-baseline/ns-vqa-master/reason/tools/preprocess_questions.py in main(args)
#      72 def main(args):
#      73
# ---> 74     labels = read_labels()
#      75
#      76     # Opening JSON file
#
# ~/Documents/clevr-poc/CLEVR-POC/nesy-baseline/ns-vqa-master/reason/tools/preprocess_questions.py in read_labels()
#      60
#      61 def read_labels():
# ---> 62         with open('../data/properties.json', encoding="utf-8") as f:
#      63             properties = json.load(f)
# ...

# %%
#PREPROCESS VAL
# %cd /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
#%run tools/preprocess_questions.py \
#--input_questions_json=/content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/data/raw/CLEVR_v1.0/questions/CLEVR_val_questions.json \
#--output_h5_file=/content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/data/reason/clevr_h5_3000/clevr_val_questions_pre.h5 \
#--input_vocab_json=/content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/data/reason/clevr_h5_3000/clevr_vocab_pre.json
# %run tools/preprocess_questions.py \
--input_questions_json=/content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/data/raw/output-2000/incomplete/questions/validation \
--output_h5_file=/content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/data/reason/output-2000/clevr_val_questions.h5 \
--input_vocab_json=/content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/data/reason/output-2000/clevr-poc-vocab.json \
--input_scenes_json=/content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/data/raw/output-2000/incomplete/scenes/validation
# Out:
# /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
# a
# Loading data
# Loading vocab given..
# Encoding data
# ##############Writing output.....
# {('single_and.json', 1): 1, ('two_hop.json', 0): 2, ('zero_hop.json', 0): 3, ('one_hop.json', 0): 4, ('three_hop.json', 1): 5, ('single_and.json', 3): 6, ('same_relate.json', 1): 7, ('two_hop.json', 1): 8, ('one_hop.json', 1): 9, ('two_hop.json', 2): 10, ('zero_hop.json', 2): 11, ('same_relate.json', 0): 12, ('zero_hop.json', 1): 13, ('same_relate.json', 10): 14, ('one_hop.json', 2): 15, ('same_relate.json', 2): 16, ('same_relate.json', 5): 17, ('same_relate.json', 4): 18, ('three_hop.json', 0): 19, ('same_relate.json', 6): 20, ('one_hop.json', 3): 21, ('same_relate.json', 7): 22, ('single_and.json', 0): 23, ('same_relate.json', 9): 24, ('three_hop.json', 2): 25, ('same_relate.json', 8): 26, ('single_and.json', 2): 27, ('same_relate.json', 3): 28}
# (200, 40)
# (200, 180)

# %%
#SAMPLING
# %cd /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
# %run tools/sample_questions.py --n_questions_per_family 3 --input_question_h5 ../data/reason/output-2000/clevr-poc-train_questions.h5 --output_dir ../data/reason/output-2000
# Out:
# /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
# | importing questions from ../data/reason/output-2000/clevr-poc-train_questions.h5
# | drawing questions, 3 per family
# sampled question family distribution
# [3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3.
#  3. 3. 3. 3.]
# | saving output file to ../data/reason/output-2000/clevr_train_3questions_per_family.h5
# | finish

# %%
#PRETRAINING
#%cd /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
#%run tools/run_train.py --scene_path ../data/raw/output-2000/incomplete/scenes/training --checkpoint_every 1000 --num_iters 10000 --run_dir ../data/reason/output-2000/model_pretrain --clevr_train_question_path ../data/reason/output-2000/clevr-poc-pretrained.h5

# %%
# %cd /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/data/reason/

# %run analyse.py
# Out:
# /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/data/reason
# PWAC::Question number: 1
# Question:  <START> What material is the cylinder that is the same size as the cyan metallic thing <END> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL> <NULL>
#
# GT: query_material unique filter_shape[cylinder] same_size unique filter_material[metal] filter_color[cyan] scene <END>
# Pred: query_material unique filter_shape[cylinder] filter_shape[cylinder] scene <END> filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green] filter_color[green]
# ...

# %%
#REINFORCE-CT
# %cd /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
# %run tools/run_train_ct.py --reinforce 1 --learning_rate 1e-5 --checkpoint_every 2000 --num_iters 900000 --run_dir ../data/reason/outputs_3000/model_reinforce_uniform_ct1M --load_checkpoint_path_ct ../data/reason/outputs_3000/model_reinforce_uniform_ct1L/checkpoint_best.pt
# Out:
# Streaming output truncated to the last 5000 lines.
# Reward =0.515625 at epoch: 79
# Reward =0.515625 at epoch: 79
# Reward =0.546875 at epoch: 79
# Reward =0.5 at epoch: 79
# Reward =0.34375 at epoch: 79
# Reward =0.46875 at epoch: 79
# Reward =0.5 at epoch: 79
# Reward =0.53125 at epoch: 79
# Reward =0.4375 at epoch: 79
# Reward =0.53125 at epoch: 79
# Reward =0.484375 at epoch: 79
# | iteration 3700 / 900000, epoch 79, reward 0.484375
# Reward =0.390625 at epoch: 79
# Reward =0.4375 at epoch: 79
# Reward =0.421875 at epoch: 79
# Reward =0.484375 at epoch: 79
# Reward =0.375 at epoch: 79
# Reward =0.34375 at epoch: 79
# Reward =0.5 at epoch: 79
# Reward =0.5 at epoch: 79
# Reward =0.5625 at epoch: 79
# Reward =0.484375 at epoch: 79
# Reward =0.46875 at epoch: 79
# Reward =0.34375 at epoch: 79
# Reward =0.48214285714285715 at epoch: 79
# Reward =0.5 at epoch: 80
# Reward =0.46875 at epoch: 80
# Reward =0.46875 at epoch: 80
# Reward =0.40625 at epoch: 80
# ...

# %%
#VALIDATION - CT
# %cd /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
# %run tools/run_test.py --load_checkpoint_path_ct ../data/reason/outputs_500/model_reinforce_uniform_500ct/checkpoint_best.pt \
--load_checkpoint_path /content/drive/MyDrive/ns-vqa-master/data/reason/outputs/model_reinforce_uniform_270pg/checkpoint_best.pt \
--clevr_val_question_path ../data/reason/clevr_h5_500/clevr_val_questions.h5 \
--clevr_val_scene_path ../data/raw/CLEVR_v1.0/scenes/CLEVR_val_scenes.json \
--save_result_path ../data/reason/results_500/result_V.json \
--clevr_vocab_path /content/drive/MyDrive/ns-vqa-master/data/reason/clevr_h5/clevr_vocab.json \
--clevr_complete_val_scene_path ../data/raw/CLEVR_v1.0/scenes/complete_val_scenes.json
# Out:
# /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
# cuda available..
# | options
# run_dir: _scratch/test_run
# dataset: clevr
# shuffle: 1
# num_workers: 8
# manual_seed: None
# gpu_ids: [0]
# visualize: 0
# clevr_train_scene_path: ../data/raw/CLEVR_v1.0/scenes/CLEVR_train_scenes.json
# clevr_complete_train_scene_path: ../data/raw/CLEVR_v1.0/scenes/complete_train_scenes.json
# clevr_complete_val_scene_path: ../data/raw/CLEVR_v1.0/scenes/complete_val_scenes.json
# clevr_constraint_scene_path: ../data/raw/CLEVR_v1.0/scenes/constraints.json
# clevr_val_scene_path: ../data/raw/CLEVR_v1.0/scenes/CLEVR_val_scenes.json
# clevr_train_question_path: ../data/reason/clevr_h5_500/clevr_train_questions.h5
# clevr_val_question_path: ../data/reason/clevr_h5_500/clevr_val_questions.h5
# train_image_path: ../data/raw/CLEVR_v1.0/images/train
# val_image_path: ../data/raw/CLEVR_v1.0/images/val
# ...

# %%
#FINE-TUNE FROM PRETRAINED NS-VQA - PRETRAINING
#%cd /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
#%run tools/run_train.py --checkpoint_every 500 --num_iters 10000 --run_dir ../data/reason/outputs_3000/model_pretrain_uniform_270pg_pre --clevr_train_question_path ../data/reason/clevr_h5_3000/clevr_train_11questions_per_family.h5 --load_checkpoint_path ../data/pretrained/question_parser.pt

# %%
#FINE TUNE NS-VQA  PRETRAINED QUESTION PARSER
#REINFORCE
#%cd /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
#%run tools/run_train.py --reinforce 1 --learning_rate 1e-5 --checkpoint_every 500 --num_iters 10000 --run_dir ../data/reason/outputs_3000/model_reinforce_uniform_270pg_pre --load_checkpoint_path ../data/reason/outputs_3000/model_pretrain_uniform_270pg_pre/checkpoint_best.pt

# %%
#PREPROCESS TEST
#%cd /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason

#%run tools/preprocess_questions.py \
#--input_questions_json=../data/raw/CLEVR_v1.0/questions/CLEVR_test_questions.json \
#--output_h5_file=../data/reason/clevr_h5_3000/clevr_test_questions_pre.h5 \
#--input_vocab_json=../data/reason/clevr_h5_3000/clevr_vocab_pre.json
# %run tools/preprocess_questions.py \
--input_questions_json=../data/raw/CLEVR_v1.0/questions/CLEVR_test_questions.json \
--output_h5_file=../data/reason/clevr_h5_3000/clevr_test_questions.h5 \
--input_vocab_json=/content/drive/MyDrive/ns-vqa-master/data/reason/clevr_h5/clevr_vocab.json
# Out:
# Loading data
# Loading vocab given..
# Encoding data
# ##############Writing output.....
# {('same_relate.json', 0): 1, ('same_relate.json', 1): 2, ('same_relate.json', 2): 3, ('same_relate.json', 3): 4, ('same_relate.json', 4): 5, ('same_relate.json', 5): 6, ('same_relate.json', 6): 7, ('same_relate.json', 7): 8, ('same_relate.json', 8): 9, ('same_relate.json', 9): 10, ('same_relate.json', 10): 11, ('single_and.json', 0): 12, ('single_and.json', 1): 13, ('single_and.json', 2): 14, ('single_and.json', 3): 15, ('one_hop.json', 0): 16, ('one_hop.json', 1): 17, ('one_hop.json', 2): 18, ('one_hop.json', 3): 19, ('two_hop.json', 0): 20, ('two_hop.json', 1): 21, ('two_hop.json', 2): 22, ('three_hop.json', 0): 23, ('three_hop.json', 1): 24, ('three_hop.json', 2): 25, ('zero_hop.json', 0): 26, ('zero_hop.json', 1): 27, ('zero_hop.json', 2): 28}
# (300, 41)
# (300, 21)

# %%
#TESTING
# %cd /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
#PRETRAINED
#%run tools/run_test.py --load_checkpoint_path ../data/pretrained/question_parser.pt \
#--clevr_val_question_path ../data/reason/clevr_h5_3000/clevr_test_questions_pre.h5 \
#--clevr_val_scene_path ../data/raw/CLEVR_v1.0/scenes/CLEVR_test_scenes.json \
#--save_result_path ../data/reason/results_3000/result_TPre.json \
#--clevr_vocab_path ../data/reason/clevr_h5_3000/clevr_vocab_pre.json \
#--clevr_complete_val_scene_path ../data/raw/CLEVR_v1.0/scenes/complete_test_scenes.json

#PRETRAINED-FINE
#%run tools/run_test.py --load_checkpoint_path ../data/reason/outputs_3000/model_reinforce_uniform_270pg_pre/checkpoint_best.pt \
#--clevr_val_question_path ../data/reason/clevr_h5_3000/clevr_test_questions_pre.h5 \
#--clevr_val_scene_path ../data/raw/CLEVR_v1.0/scenes/CLEVR_test_scenes.json \
#--save_result_path ../data/reason/results_3000/result_TPreFR.json \
#--clevr_vocab_path ../data/reason/clevr_h5_3000/clevr_vocab_pre.json \
#--clevr_complete_val_scene_path ../data/raw/CLEVR_v1.0/scenes/complete_test_scenes.json

#SCRATCH
# %run tools/run_test.py --load_checkpoint_path_ct ../data/reason/outputs_3000/model_reinforce_uniform_ct/checkpoint_best.pt \
--clevr_val_question_path ../data/reason/clevr_h5_3000/clevr_test_questions.h5 \
--load_checkpoint_path /content/drive/MyDrive/ns-vqa-master/data/reason/outputs/model_reinforce_uniform_270pg_15M/checkpoint_best.pt \
--clevr_val_scene_path ../data/raw/CLEVR_v1.0/scenes/CLEVR_test_scenes.json \
--save_result_path ../data/reason/results_3000/result_TS.json \
--clevr_vocab_path /content/drive/MyDrive/ns-vqa-master/data/reason/clevr_h5/clevr_vocab.json \
--clevr_complete_val_scene_path ../data/raw/CLEVR_v1.0/scenes/complete_test_scenes.json
# Out:
# /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
# cuda available..
# | options
# run_dir: _scratch/test_run
# dataset: clevr
# shuffle: 1
# num_workers: 8
# manual_seed: None
# gpu_ids: [0]
# visualize: 0
# clevr_train_scene_path: ../data/raw/CLEVR_v1.0/scenes/CLEVR_train_scenes.json
# clevr_complete_train_scene_path: ../data/raw/CLEVR_v1.0/scenes/complete_train_scenes.json
# clevr_complete_val_scene_path: ../data/raw/CLEVR_v1.0/scenes/complete_test_scenes.json
# clevr_constraint_scene_path: ../data/raw/CLEVR_v1.0/scenes/constraints.json
# clevr_val_scene_path: ../data/raw/CLEVR_v1.0/scenes/CLEVR_test_scenes.json
# clevr_train_question_path: ../data/reason/clevr_h5_3000/clevr_train_questions.h5
# clevr_val_question_path: ../data/reason/clevr_h5_3000/clevr_test_questions.h5
# train_image_path: ../data/raw/CLEVR_v1.0/images/train
# val_image_path: ../data/raw/CLEVR_v1.0/images/val
# ...

# %%
#%cd /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/data/outputs_3000
#%rm -r /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/data/reason/outputs_3000/model_pretrain_uniform_270pg_sam
#VALIDATION TESTING - SCRATCH
#%cd /content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason
#%run tools/run_test.py --load_checkpoint_path ../data/reason/outputs_500/model_pretrain_uniform_270pg/checkpoint_best.pt \
#--clevr_val_question_path ../data/reason/clevr_h5_500/clevr_val_questions.h5 \
#--clevr_val_scene_path ../data/raw/CLEVR_v1.0/scenes/CLEVR_val_scenes.json \
#--save_result_path ../data/reason/results_500/result_V.json \
#--clevr_vocab_path ../data/reason/clevr_h5_500/clevr_vocab.json \
#--clevr_complete_val_scene_path ../data/raw/CLEVR_v1.0/scenes/complete_val_scenes.json

#VALIDATION PRE-FINE
#%run tools/run_test.py --load_checkpoint_path ../data/reason/outputs_3000/model_reinforce_uniform_270pg_pre/checkpoint_best.pt \
#--clevr_val_question_path ../data/reason/clevr_h5_3000/clevr_val_questions_pre.h5 \
#--clevr_val_scene_path ../data/raw/CLEVR_v1.0/scenes/CLEVR_val_scenes.json \
#--save_result_path ../data/reason/results_3000/result_VPreFR.json \
#--clevr_vocab_path ../data/reason/clevr_h5_3000/clevr_vocab_pre.json \
#--clevr_complete_val_scene_path ../data/raw/CLEVR_v1.0/scenes/complete_val_scenes.json

#VALIDATION TESTING PRE VOCAB, pRE-MODEL
#%run tools/run_test.py --load_checkpoint_path ../data/pretrained/question_parser.pt \
#--clevr_val_question_path ../data/reason/clevr_h5_3000/clevr_val_questions_pre.h5 \
#--clevr_val_scene_path ../data/raw/CLEVR_v1.0/scenes/CLEVR_val_scenes.json \
#--save_result_path ../data/reason/results_3000/result_VPre.json \
#--clevr_vocab_path ../data/reason/clevr_h5_3000/clevr_vocab_pre.json \
#--clevr_complete_val_scene_path ../data/raw/CLEVR_v1.0/scenes/complete_val_scenes.json
